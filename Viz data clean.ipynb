# %%
# print all the outputs in a cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd

# %%
import os
os.chdir("/Users/zouxin/Downloads/Viz")

# %%
os.getcwd()
# Out:
# '/Users/zouxin/Downloads/Viz'

# %%
pd.options.display.max_columns = 999

# %%
df1  = pd.read_csv('Speed_Camera_Violations0426.csv')

# %%
df1.head()
# Out:
#                 ADDRESS CAMERA ID VIOLATION DATE  VIOLATIONS  X COORDINATE  \
# 0  10318 S INDIANAPOLIS    CHI120     04/12/2019          93  1.203645e+06
# 1     1110 S PULASKI RD    CHI163     04/12/2019           9  1.149841e+06
# 2       1111 N HUMBOLDT    CHI010     04/12/2019          60           NaN
# 3     11144 S VINCENNES    CHI023     04/12/2019          23  1.166994e+06
# 4     11153 S VINCENNES    CHI022     04/12/2019          25  1.167029e+06
#
#    Y COORDINATE   LATITUDE  LONGITUDE  \
# 0  1.837056e+06  41.707577 -87.529848
# 1  1.894931e+06  41.867603 -87.725383
# 2           NaN        NaN        NaN
# 3  1.830711e+06  41.691025 -87.664248
# 4  1.830594e+06  41.690702 -87.664122
#
#                                    LOCATION  Historical Wards 2003-2015  \
# 0   (41.70757690291348, -87.52984826112849)                        47.0
# 1    (41.86760272243294, -87.7253827433152)                        36.0
# ...

# %%
df2 = pd.read_csv("Chicago_Active_Camera_Schedule.csv")

# %%
df2.head()
# Out:
#   # of Sites      ID          Address           Zone Warning Live  \
# 0          1  CHI003   4124  W Foster   Gompers Park    8/26/2013
# 1          2  CHI004   5120 N Pulaski   Gompers Park    8/26/2013
# 2          3  CHI005  2080 W Pershing  McKinley Park     9/7/2013
# 3          4  CHI007   3843 S Western  McKinley Park     9/7/2013
# 4          5  CHI008   3655 W Jackson  Garfield Park    9/10/2013
#
#   Citation Live
# 0    10/16/2013
# 1    10/16/2013
# 2    10/22/2013
# 3    10/22/2013
# 4    10/25/2013

# %%
df3 = pd.read_csv("CCASF12010CMAP.csv")

# %%
df3.head()
# Out:
#              Geog  Community Areas  Total Population  \
# 0     Rogers Park                1             54991
# 1      West Ridge                2             71942
# 2          Uptown                3             56362
# 3  Lincoln Square                4             39493
# 4    North Center                5             31867
#
#    Not Hispanic or Latino, White alone  \
# 0                                21618
# 1                                30706
# 2                                29098
# 3                                24916
# 4                                24634
#
#    Not Hispanic or Latino, Black or African American alone  \
# 0                                              14461
# 1                                               8015
# 2                                              11275
# 3                                               1488
# 4                                                738
#
#    Not Hispanic or Latino, American Indian and Alaska Native alone  \
# ...

# %%
df3.drop(df3.iloc[:,67:129],inplace = True, axis = 1)

# %%
df4 = pd.read_csv("Speed_Camera_Locations0426.csv")

# %%
df4.head()
# Out:
#                      ADDRESS FIRST APPROACH SECOND APPROACH GO-LIVE DATE  \
# 0        5454 W Irving Park              EB              WB     11/10/13
# 1            3534 N Western              SB             NaN      1/31/14
# 2        8345 S Ashland Ave              NB             NaN     10/11/14
# 3  7122 S South Chicago Ave             SEB             NaN      8/20/18
# 4          732 N Pulaski Rd              NB              SB      3/24/14
#
#     LATITUDE  LONGITUDE                                  LOCATION  \
# 0  41.953330 -87.764267   (41.95332954454448, -87.76426726425451)
# 1  41.945963 -87.688384    (41.9459625867886, -87.68838396394528)
# 2  41.741742 -87.663073  (41.741741651401504, -87.66307332925098)
# 3  41.765164 -87.604804                   (41.765164, -87.604804)
# 4  41.894503 -87.726205   (41.89450330881178, -87.72620452246953)
#
#    Historical Wards 2003-2015 Zip Codes  Community Areas  Census Tracts  Wards
# ...

# %%
df2.rename(columns={'ID' : 'CAMERA ID'},inplace=True)

# %%
# Out:
#   # of Sites CAMERA ID          Address           Zone Warning Live  \
# 0          1    CHI003   4124  W Foster   Gompers Park    8/26/2013
# 1          2    CHI004   5120 N Pulaski   Gompers Park    8/26/2013
# 2          3    CHI005  2080 W Pershing  McKinley Park     9/7/2013
# 3          4    CHI007   3843 S Western  McKinley Park     9/7/2013
# 4          5    CHI008   3655 W Jackson  Garfield Park    9/10/2013
#
#   Citation Live
# 0    10/16/2013
# 1    10/16/2013
# 2    10/22/2013
# 3    10/22/2013
# 4    10/25/2013

# %%
len(df1)
# Out:
# 183678

# %%
D1 = df1.merge(df2,on="CAMERA ID",how = "right")

# %%
D1.head()
# Out:
#                 ADDRESS CAMERA ID VIOLATION DATE  VIOLATIONS  X COORDINATE  \
# 0  10318 S INDIANAPOLIS    CHI120     04/12/2019          93  1.203645e+06
# 1  10318 S INDIANAPOLIS    CHI120     04/11/2019          89  1.203645e+06
# 2  10318 S INDIANAPOLIS    CHI120     04/10/2019          81  1.203645e+06
# 3  10318 S INDIANAPOLIS    CHI120     04/09/2019          50  1.203645e+06
# 4  10318 S INDIANAPOLIS    CHI120     04/08/2019          87  1.203645e+06
#
#    Y COORDINATE   LATITUDE  LONGITUDE  \
# 0  1.837056e+06  41.707577 -87.529848
# 1  1.837056e+06  41.707577 -87.529848
# 2  1.837056e+06  41.707577 -87.529848
# 3  1.837056e+06  41.707577 -87.529848
# 4  1.837056e+06  41.707577 -87.529848
#
#                                   LOCATION  Historical Wards 2003-2015  \
# 0  (41.70757690291348, -87.52984826112849)                        47.0
# 1  (41.70757690291348, -87.52984826112849)                        47.0
# ...

# %%
D2= D1.merge(df3,on="Community Areas",how = "right")

# %%
len(D2)
# Out:
# 179115

# %%
D2.head()
# Out:
#                 ADDRESS CAMERA ID VIOLATION DATE  VIOLATIONS  X COORDINATE  \
# 0  10318 S INDIANAPOLIS    CHI120     04/12/2019        93.0  1.203645e+06
# 1  10318 S INDIANAPOLIS    CHI120     04/11/2019        89.0  1.203645e+06
# 2  10318 S INDIANAPOLIS    CHI120     04/10/2019        81.0  1.203645e+06
# 3  10318 S INDIANAPOLIS    CHI120     04/09/2019        50.0  1.203645e+06
# 4  10318 S INDIANAPOLIS    CHI120     04/08/2019        87.0  1.203645e+06
#
#    Y COORDINATE   LATITUDE  LONGITUDE  \
# 0  1.837056e+06  41.707577 -87.529848
# 1  1.837056e+06  41.707577 -87.529848
# 2  1.837056e+06  41.707577 -87.529848
# 3  1.837056e+06  41.707577 -87.529848
# 4  1.837056e+06  41.707577 -87.529848
#
#                                   LOCATION  Historical Wards 2003-2015  \
# 0  (41.70757690291348, -87.52984826112849)                        47.0
# 1  (41.70757690291348, -87.52984826112849)                        47.0
# ...

# %%
D2.to_csv("data1.csv")

# %%
D3= pd.read_csv("data1.csv")
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
D3.head()
# Out:
#    Unnamed: 0               ADDRESS CAMERA ID VIOLATION DATE  VIOLATIONS  \
# 0           0  10318 S INDIANAPOLIS    CHI120        4/12/19        93.0
# 1           1  10318 S INDIANAPOLIS    CHI120        4/11/19        89.0
# 2           2  10318 S INDIANAPOLIS    CHI120        4/10/19        81.0
# 3           3  10318 S INDIANAPOLIS    CHI120         4/9/19        50.0
# 4           4  10318 S INDIANAPOLIS    CHI120         4/8/19        87.0
#
#    X COORDINATE  Y COORDINATE   LATITUDE  LONGITUDE  \
# 0   1203645.368   1837056.145  41.707577 -87.529848
# 1   1203645.368   1837056.145  41.707577 -87.529848
# 2   1203645.368   1837056.145  41.707577 -87.529848
# 3   1203645.368   1837056.145  41.707577 -87.529848
# 4   1203645.368   1837056.145  41.707577 -87.529848
#
#                                   LOCATION  Historical Wards 2003-2015  \
# 0  (41.70757690291348, -87.52984826112849)                        47.0
# ...

# %%
D3.rename(columns={'Historical Wards 2003-2015' : 'Historical'},inplace=True)

# %%
D3["ChangeWard"] = D3.Historical != D3.Wards
D3["ChangeWard"] = (True)*1

# %%
D3.head()
# Out:
#    Unnamed: 0               ADDRESS CAMERA ID VIOLATION DATE  VIOLATIONS  \
# 0           0  10318 S INDIANAPOLIS    CHI120        4/12/19        93.0
# 1           1  10318 S INDIANAPOLIS    CHI120        4/11/19        89.0
# 2           2  10318 S INDIANAPOLIS    CHI120        4/10/19        81.0
# 3           3  10318 S INDIANAPOLIS    CHI120         4/9/19        50.0
# 4           4  10318 S INDIANAPOLIS    CHI120         4/8/19        87.0
#
#    X COORDINATE  Y COORDINATE   LATITUDE  LONGITUDE  \
# 0   1203645.368   1837056.145  41.707577 -87.529848
# 1   1203645.368   1837056.145  41.707577 -87.529848
# 2   1203645.368   1837056.145  41.707577 -87.529848
# 3   1203645.368   1837056.145  41.707577 -87.529848
# 4   1203645.368   1837056.145  41.707577 -87.529848
#
#                                   LOCATION  Historical Zip Codes  \
# 0  (41.70757690291348, -87.52984826112849)        47.0    21,202
# 1  (41.70757690291348, -87.52984826112849)        47.0    21,202
# ...

# %%
D3.to_csv("data2.csv")
